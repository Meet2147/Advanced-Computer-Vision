# %%
# !git clone https://github.com/matterport/Mask_RCNN.git
# Out:
# Cloning into 'Mask_RCNN'...
# remote: Enumerating objects: 956, done.
# remote: Total 956 (delta 0), reused 0 (delta 0), pack-reused 956
# Receiving objects: 100% (956/956), 111.81 MiB | 10.78 MiB/s, done.
# Resolving deltas: 100% (571/571), done.

# %%
# !unzip /content/customdataset.zip
# Out:
# Archive:  /content/customdataset.zip
#    creating: customdataset/train/
#   inflating: customdataset/train/image1.jpeg
#   inflating: customdataset/train/image10.jpg
#   inflating: customdataset/train/image13.jpg
#   inflating: customdataset/train/image14.jpg
#   inflating: customdataset/train/image15.jpg
#   inflating: customdataset/train/image16.jpg
#   inflating: customdataset/train/image17.jpg
#   inflating: customdataset/train/image18.jpeg
#   inflating: customdataset/train/image19.jpeg
#   inflating: customdataset/train/image2.jpg
#   inflating: customdataset/train/image21.jpeg
#   inflating: customdataset/train/image28.jpg
#   inflating: customdataset/train/image3.jpg
#   inflating: customdataset/train/image33.jpg
#   inflating: customdataset/train/image38.jpg
#   inflating: customdataset/train/image39.jpg
#   inflating: customdataset/train/image4.jpg
#   inflating: customdataset/train/image40.jpeg
#   inflating: customdataset/train/image42.jpg
#   inflating: customdataset/train/image43.jpg
#   inflating: customdataset/train/image44.jpg
#   inflating: customdataset/train/image45.jpg
#   inflating: customdataset/train/image46.jpeg
#   inflating: customdataset/train/image47.jpg
#   inflating: customdataset/train/image48.jpg
#   inflating: customdataset/train/image49.jpg
#   inflating: customdataset/train/image5.jpeg
#   inflating: customdataset/train/image50.jpg
#   inflating: customdataset/train/image51.png
#   inflating: customdataset/train/image52.jpg
#   inflating: customdataset/train/image53.jpg
#   inflating: customdataset/train/image54.jpg
#   inflating: customdataset/train/image55.jpeg
#   inflating: customdataset/train/image56.jpg
#   inflating: customdataset/train/image57.jpg
#   inflating: customdataset/train/image58.jpg
#   inflating: customdataset/train/image59.png
#   inflating: customdataset/train/image6.png
#   inflating: customdataset/train/image60.jpg
#   inflating: customdataset/train/image61.jpg
#   inflating: customdataset/train/image62.jpg
#   inflating: customdataset/train/image63.jpg
#   inflating: customdataset/train/image64.jpg
#   inflating: customdataset/train/image65.jpg
#   inflating: customdataset/train/image66.jpg
#   inflating: customdataset/train/image67.jpg
#   inflating: customdataset/train/image7.jpg
#   inflating: customdataset/train/image8.jpg
#   inflating: customdataset/train/image9.jpeg
#   inflating: customdataset/train/via_region_data.json
#    creating: customdataset/val/
#   inflating: customdataset/val/image61.jpeg
#   inflating: customdataset/val/image62.jpg
#   inflating: customdataset/val/image63.jpg
#   inflating: customdataset/val/image64.jpg
#   inflating: customdataset/val/image65.jpg
#   inflating: customdataset/val/image72.jpeg
#   inflating: customdataset/val/image73.jpg
#   inflating: customdataset/val/image74.jpeg
#   inflating: customdataset/val/image75.jpeg
#   inflating: customdataset/val/image75.jpg
#   inflating: customdataset/val/image76.jpg
#   inflating: customdataset/val/image77.jpg
#   inflating: customdataset/val/image78.jpg
#   inflating: customdataset/val/image79.jpg
#   inflating: customdataset/val/image80.jpg
#   inflating: customdataset/val/via_region_data.json

# %%
# !mv custom.py Mask_RCNN/
#!unzip /content/customdataset.zip

# %%
# %cd Mask_RCNN/
# !mkdir train_logs
# !python3 custom.py train --dataset=/content/customdataset --weights=coco --logs=/content/Mask_RCNN/train_logs/
# Out:
# /content/Mask_RCNN
# Using TensorFlow backend.
# Weights:  coco
# Dataset:  /content/customdataset
# Logs:  /content/Mask_RCNN/train_logs/
#
# Configurations:
# BACKBONE                       resnet101
# BACKBONE_STRIDES               [4, 8, 16, 32, 64]
# BATCH_SIZE                     2
# BBOX_STD_DEV                   [0.1 0.1 0.2 0.2]
# COMPUTE_BACKBONE_SHAPE         None
# DETECTION_MAX_INSTANCES        100
# DETECTION_MIN_CONFIDENCE       0.9
# DETECTION_NMS_THRESHOLD        0.3
# FPN_CLASSIF_FC_LAYERS_SIZE     1024
# GPU_COUNT                      1
# GRADIENT_CLIP_NORM             5.0
# IMAGES_PER_GPU                 2
# IMAGE_CHANNEL_COUNT            3
# IMAGE_MAX_DIM                  1024
# IMAGE_META_SIZE                14
# IMAGE_MIN_DIM                  800
# IMAGE_MIN_SCALE                0
# IMAGE_RESIZE_MODE              square
# IMAGE_SHAPE                    [1024 1024    3]
# LEARNING_MOMENTUM              0.9
# LEARNING_RATE                  0.001
# LOSS_WEIGHTS                   {'rpn_class_loss': 1.0, 'rpn_bbox_loss': 1.0, 'mrcnn_class_loss': 1.0, 'mrcnn_bbox_loss': 1.0, 'mrcnn_mask_loss': 1.0}
# MASK_POOL_SIZE                 14
# MASK_SHAPE                     [28, 28]
# MAX_GT_INSTANCES               100
# MEAN_PIXEL                     [123.7 116.8 103.9]
# MINI_MASK_SHAPE                (56, 56)
# NAME                           damage
# NUM_CLASSES                    2
# POOL_SIZE                      7
# POST_NMS_ROIS_INFERENCE        1000
# POST_NMS_ROIS_TRAINING         2000
# PRE_NMS_LIMIT                  6000
# ROI_POSITIVE_RATIO             0.33
# RPN_ANCHOR_RATIOS              [0.5, 1, 2]
# RPN_ANCHOR_SCALES              (32, 64, 128, 256, 512)
# RPN_ANCHOR_STRIDE              1
# RPN_BBOX_STD_DEV               [0.1 0.1 0.2 0.2]
# RPN_NMS_THRESHOLD              0.7
# RPN_TRAIN_ANCHORS_PER_IMAGE    256
# STEPS_PER_EPOCH                100
# TOP_DOWN_PYRAMID_SIZE          256
# TRAIN_BN                       False
# TRAIN_ROIS_PER_IMAGE           200
# USE_MINI_MASK                  True
# USE_RPN_ROIS                   True
# VALIDATION_STEPS               50
# WEIGHT_DECAY                   0.0001
#
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:541: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:66: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4432: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:2139: The name tf.nn.fused_batch_norm is deprecated. Please use tf.compat.v1.nn.fused_batch_norm instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4267: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:2239: The name tf.image.resize_nearest_neighbor is deprecated. Please use tf.compat.v1.image.resize_nearest_neighbor instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/ops/array_ops.py:1475: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# WARNING:tensorflow:From /content/Mask_RCNN/mrcnn/model.py:553: The name tf.random_shuffle is deprecated. Please use tf.random.shuffle instead.
#
# WARNING:tensorflow:From /content/Mask_RCNN/mrcnn/utils.py:202: The name tf.log is deprecated. Please use tf.math.log instead.
#
# WARNING:tensorflow:From /content/Mask_RCNN/mrcnn/model.py:600: calling crop_and_resize_v1 (from tensorflow.python.ops.image_ops_impl) with box_ind is deprecated and will be removed in a future version.
# Instructions for updating:
# box_ind is deprecated, use box_indices instead
# Downloading pretrained model to /mask_rcnn_coco.h5 ...
# ... done downloading pretrained model!
- rpn_class_loss: 0.0113 - rpn_bbox_loss: 0.1459 - mrcnn_class_loss: 0.0569 - mrcnn_bbox_loss: 0.1822 - mrcnn_mask_loss: 0.2460 - val_loss: 1.8678 - val_rpn_class_loss: 0.0363 - val_rpn_bbox_loss: 0.7234 - val_mrcnn_class_loss: 0.0628 - val_mrcnn_bbox_loss: 0.5594 - val_mrcnn_mask_loss: 0.4859
# Epoch 7/10
# 100/100 [==============================] - 68s 685ms/step - loss: 0.4927 - rpn_class_loss: 0.0097 - rpn_bbox_loss: 0.0911 - mrcnn_class_loss: 0.0482 - mrcnn_bbox_loss: 0.1294 - mrcnn_mask_loss: 0.2143 - val_loss: 2.0933 - val_rpn_class_loss: 0.0393 - val_rpn_bbox_loss: 0.8975 - val_mrcnn_class_loss: 0.0617 - val_mrcnn_bbox_loss: 0.5643 - val_mrcnn_mask_loss: 0.5305
# Epoch 8/10
# 100/100 [==============================] - 68s 684ms/step - loss: 0.4044 - rpn_class_loss: 0.0083 - rpn_bbox_loss: 0.0796 - mrcnn_class_loss: 0.0400 - mrcnn_bbox_loss: 0.0922 - mrcnn_mask_loss: 0.1843 - val_loss: 2.0215 - val_rpn_class_loss: 0.0373 - val_rpn_bbox_loss: 0.8238 - val_mrcnn_class_loss: 0.0605 - val_mrcnn_bbox_loss: 0.5109 - val_mrcnn_mask_loss: 0.5890
# Epoch 9/10
# 100/100 [==============================] - 68s 683ms/step - loss: 0.3198 - rpn_class_loss: 0.0055 - rpn_bbox_loss: 0.0554 - mrcnn_class_loss: 0.0321 - mrcnn_bbox_loss: 0.0671 - mrcnn_mask_loss: 0.1597 - val_loss: 2.1357 - val_rpn_class_loss: 0.0351 - val_rpn_bbox_loss: 0.8542 - val_mrcnn_class_loss: 0.0610 - val_mrcnn_bbox_loss: 0.5445 - val_mrcnn_mask_loss: 0.6410
# Epoch 10/10
# 100/100 [==============================] - 68s 681ms/step - loss: 0.3122 - rpn_class_loss: 0.0065 - rpn_bbox_loss: 0.0429 - mrcnn_class_loss: 0.0303 - mrcnn_bbox_loss: 0.0656 - mrcnn_mask_loss: 0.1669 - val_loss: 2.3893 - val_rpn_class_loss: 0.0498 - val_rpn_bbox_loss: 1.0600 - val_mrcnn_class_loss: 0.0617 - val_mrcnn_bbox_loss: 0.5364 - val_mrcnn_mask_loss: 0.6814

# %% [markdown]
# #### IMPORT THE REQUIRED LIBRARIES

# %%
import os
import cv2
import sys
import random
import math
import re
import time
import numpy as np
import tensorflow as tf
import matplotlib
import matplotlib.pyplot as plt
import matplotlib.patches as patches
import skimage
import glob
# Root directory of the project
ROOT_DIR = os.getcwd()
# Import Mask RCNN
sys.path.append(ROOT_DIR)  # To find local version of the library
from mrcnn import utils
from mrcnn import visualize
from mrcnn.visualize import display_images
import mrcnn.model as modellib
from mrcnn.model import log
import custom
# %matplotlib inline
# Directory to save logs and trained model
MODEL_DIR = os.path.join(ROOT_DIR, "train_logs/damage20191117T0756")
custom_WEIGHTS_PATH = "mask_rcnn_damage_0001.h5"  # TODO: update this path
config = custom.CustomConfig()
custom_DIR = '/content/customdataset'

# %%
class InferenceConfig(config.__class__):
   # Run detection on one image at a time
   GPU_COUNT = 1
   IMAGES_PER_GPU = 1
config = InferenceConfig()
config.display()
# Out:
# Configurations:
# BACKBONE                       resnet101
# BACKBONE_STRIDES               [4, 8, 16, 32, 64]
# BATCH_SIZE                     1
# BBOX_STD_DEV                   [0.1 0.1 0.2 0.2]
# COMPUTE_BACKBONE_SHAPE         None
# DETECTION_MAX_INSTANCES        100
# DETECTION_MIN_CONFIDENCE       0.9
# DETECTION_NMS_THRESHOLD        0.3
# FPN_CLASSIF_FC_LAYERS_SIZE     1024
# GPU_COUNT                      1
# GRADIENT_CLIP_NORM             5.0
# IMAGES_PER_GPU                 1
# IMAGE_CHANNEL_COUNT            3
# IMAGE_MAX_DIM                  1024
# IMAGE_META_SIZE                14
# IMAGE_MIN_DIM                  800
# IMAGE_MIN_SCALE                0
# IMAGE_RESIZE_MODE              square
# IMAGE_SHAPE                    [1024 1024    3]
# LEARNING_MOMENTUM              0.9
# LEARNING_RATE                  0.001
# LOSS_WEIGHTS                   {'rpn_class_loss': 1.0, 'rpn_bbox_loss': 1.0, 'mrcnn_class_loss': 1.0, 'mrcnn_bbox_loss': 1.0, 'mrcnn_mask_loss': 1.0}
# MASK_POOL_SIZE                 14
# MASK_SHAPE                     [28, 28]
# MAX_GT_INSTANCES               100
# MEAN_PIXEL                     [123.7 116.8 103.9]
# MINI_MASK_SHAPE                (56, 56)
# NAME                           damage
# NUM_CLASSES                    2
# POOL_SIZE                      7
# POST_NMS_ROIS_INFERENCE        1000
# POST_NMS_ROIS_TRAINING         2000
# PRE_NMS_LIMIT                  6000
# ROI_POSITIVE_RATIO             0.33
# RPN_ANCHOR_RATIOS              [0.5, 1, 2]
# RPN_ANCHOR_SCALES              (32, 64, 128, 256, 512)
# RPN_ANCHOR_STRIDE              1
# RPN_BBOX_STD_DEV               [0.1 0.1 0.2 0.2]
# RPN_NMS_THRESHOLD              0.7
# RPN_TRAIN_ANCHORS_PER_IMAGE    256
# STEPS_PER_EPOCH                100
# TOP_DOWN_PYRAMID_SIZE          256
# TRAIN_BN                       False
# TRAIN_ROIS_PER_IMAGE           200
# USE_MINI_MASK                  True
# USE_RPN_ROIS                   True
# VALIDATION_STEPS               50
# WEIGHT_DECAY                   0.0001

# %%
DEVICE = "/gpu:0"  # /cpu:0 or /gpu:0
# Inspect the model in training or inference modes
# values: 'inference' or 'training'
# TODO: code for 'training' test mode not ready yet
TEST_MODE = "inference"
def get_ax(rows=1, cols=1, size=16):
   """Return a Matplotlib Axes array to be used in
   all visualizations in the notebook. Provide a
   central point to control graph sizes.
   Adjust the size attribute to control how big to render images
   """
   _, ax = plt.subplots(rows, cols, figsize=(size*cols, size*rows))
   return ax
# Load validation dataset
dataset = custom.CustomDataset()
dataset.load_custom(custom_DIR, "val")
# Must call before using the dataset
dataset.prepare()
print("Images: {}\nClasses: {}".format(len(dataset.image_ids), dataset.class_names))
# Create model in inference mode
with tf.device(DEVICE):
   model = modellib.MaskRCNN(mode="inference", model_dir=MODEL_DIR,
                             config=config)
# Load weights
print("Loading weights ", custom_WEIGHTS_PATH)
model.load_weights(MODEL_DIR+'/'+custom_WEIGHTS_PATH, by_name=True)
image_id = random.choice(dataset.image_ids)
image, image_meta, gt_class_id, gt_bbox, gt_mask =\
   modellib.load_image_gt(dataset, config, image_id, use_mini_mask=False)
info = dataset.image_info[image_id]
print("image ID: {}.{} ({}) {}".format(info["source"], info["id"], image_id,
                                      dataset.image_reference(image_id)))
# Run object detection
results = model.detect([image], verbose=1)
# Display results
ax = get_ax(1)
r = results[0]
visualize.display_instances(image, r['rois'], r['masks'], r['class_ids'],
                           dataset.class_names, r['scores'], ax=ax,
                           title="Predictions")
# Out:
# Images: 15
# Classes: ['BG', 'damage']
# Loading weights  mask_rcnn_damage_0001.h5
# Re-starting from epoch 1
# image ID: damage.image78.jpg (3) /content/customdataset/val/image78.jpg
# Processing 1 images
# image                    shape: (1024, 1024, 3)       min:    0.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  151.10000  float64
# image_metas              shape: (1, 14)               min:    0.00000  max: 1024.00000  int64
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
